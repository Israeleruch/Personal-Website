# %% [markdown]
# # Tutorial 3: Pandas

# %%
#As always, begin by importing the necessary packages.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Now, we read a CSV file and insert it into a Pandas dataframe.

df = pd.read_csv("C:/Users/eruch/Dropbox/Haifa Courses/Graduate Macroeconomic Theory 2/Python/Python Code/P2-Demographic-Data.csv")
df
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#The head() method.

df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#The describe() method.

df.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %% [markdown]
# ## Selecting Data by Location

# %%
#Select specific rows using standard numerical indexing.

df[24:115:5]
# Out:
#                  Country Name Country Code  Birth rate  Internet users  \
# 24                     Brazil          BRA      14.931         51.0400
# 29   Central African Republic          CAF      34.076          3.5000
# 34              Cote d'Ivoire          CIV      37.320          8.4000
# 39                 Cabo Verde          CPV      21.625         37.5000
# 44             Czech Republic          CZE      10.200         74.1104
# 49                    Algeria          DZA      24.738         16.5000
# 54                    Estonia          EST      10.300         79.4000
# 59      Micronesia, Fed. Sts.          FSM      23.511         27.8000
# 64                     Guinea          GIN      37.337          1.6000
# 69                    Grenada          GRD      19.334         35.0000
# 74       Hong Kong SAR, China          HKG       7.900         74.2000
# 79                  Indonesia          IDN      20.297         14.9400
# ...

# %%
df[-40:-5]
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 155                     El Salvador          SLV      17.476         23.1093
# 156                         Somalia          SOM      43.891          1.5000
# 157                          Serbia          SRB       9.200         51.5000
# 158                     South Sudan          SSD      37.126         14.1000
# 159           Sao Tome and Principe          STP      34.537         23.0000
# 160                        Suriname          SUR      18.455         37.4000
# 161                 Slovak Republic          SVK      10.100         77.8826
# 162                        Slovenia          SVN      10.200         72.6756
# 163                          Sweden          SWE      11.800         94.7836
# 164                       Swaziland          SWZ      30.093         24.7000
# 165                      Seychelles          SYC      18.600         50.4000
# ...

# %%
df[::-1]
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 194              Zimbabwe          ZWE      35.715            18.5
# 193                Zambia          ZMB      40.471            15.4
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 191          South Africa          ZAF      20.850            46.5
# 190           Yemen, Rep.          YEM      32.947            20.0
# ..                    ...          ...         ...             ...
# 4    United Arab Emirates          ARE      11.044            88.0
# 3                 Albania          ALB      12.877            57.2
# 2                  Angola          AGO      45.985            19.1
# 1             Afghanistan          AFG      35.253             5.9
# 0                   Aruba          ABW      10.244            78.9
#
#             Income Group
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ...

# %%
#Select specific columns by their names.

df[["Country Code", "Internet users", "Income Group"]]
# Out:
#     Country Code  Internet users         Income Group
# 0            ABW            78.9          High income
# 1            AFG             5.9           Low income
# 2            AGO            19.1  Upper middle income
# 3            ALB            57.2  Upper middle income
# 4            ARE            88.0          High income
# ..           ...             ...                  ...
# 190          YEM            20.0  Lower middle income
# 191          ZAF            46.5  Upper middle income
# 192          COD             2.2           Low income
# 193          ZMB            15.4  Lower middle income
# 194          ZWE            18.5           Low income
#
# [195 rows x 3 columns]

# %%
#Select both rows and columns: method #1.

df[["Country Name", "Birth rate", "Income Group"]][45:56]
# Out:
#           Country Name  Birth rate         Income Group
# 45             Germany       8.500          High income
# 46            Djibouti      25.486  Lower middle income
# 47             Denmark      10.000          High income
# 48  Dominican Republic      21.198  Upper middle income
# 49             Algeria      24.738  Upper middle income
# 50             Ecuador      21.070  Upper middle income
# 51    Egypt, Arab Rep.      28.032  Lower middle income
# 52             Eritrea      34.800           Low income
# 53               Spain       9.100          High income
# 54             Estonia      10.300          High income
# 55            Ethiopia      32.925           Low income

# %%
#Select both rows and columns: method #2.

df.iloc[112:116, 2:5]
# Out:
#      Birth rate  Internet users         Income Group
# 112      21.447           44.10  Upper middle income
# 113      19.104           43.46  Upper middle income
# 114      11.222           65.24  Upper middle income
# 115      44.138            3.50           Low income

# %%
#Select both rows and columns: method #3.

df.loc[88:112:3, ["Country Name", "Internet users"]]
# Out:
#     Country Name  Internet users
# 88        Jordan         41.0000
# 91         Kenya         39.0000
# 94      Kiribati         11.5000
# 97       Lao PDR         12.5000
# 100        Libya         16.5000
# 103    Sri Lanka         21.9000
# 106   Luxembourg         93.7765
# 109      Morocco         56.0000
# 112     Maldives         44.1000

# %% [markdown]
# ## Selecting Data by Conditions

# %%
#Select rows by a single condition.

df[df["Birth rate"] > 40]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 2              Angola          AGO      45.985            19.1
# 11            Burundi          BDI      44.151             1.3
# 14       Burkina Faso          BFA      40.551             9.1
# 65        Gambia, The          GMB      42.525            14.0
# 115              Mali          MLI      44.138             3.5
# 127             Niger          NER      49.661             1.7
# 128           Nigeria          NGA      40.045            38.0
# 156           Somalia          SOM      43.891             1.5
# 167              Chad          TCD      45.745             2.3
# 178            Uganda          UGA      43.474            16.2
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
#
#             Income Group
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# ...

# %%
df[df["Income Group"].isin(["High income", "Upper middle income"])]
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244            78.9
# 2                            Angola          AGO      45.985            19.1
# 3                           Albania          ALB      12.877            57.2
# 4              United Arab Emirates          ARE      11.044            88.0
# 5                         Argentina          ARG      17.716            59.9
# ..                              ...          ...         ...             ...
# 181                   United States          USA      12.500            84.2
# 183  St. Vincent and the Grenadines          VCT      16.306            52.0
# 184                   Venezuela, RB          VEN      19.842            54.9
# 185           Virgin Islands (U.S.)          VIR      10.700            45.3
# 191                    South Africa          ZAF      20.850            46.5
#
#             Income Group
# ...

# %%
#Select rows by multiple conditions using the "and" operator.

df[(df["Birth rate"] < 15) & (df["Internet users"] > 90)]
# Out:
#       Country Name Country Code  Birth rate  Internet users Income Group
# 22         Bermuda          BMU        10.4         95.3000  High income
# 47         Denmark          DNK        10.0         94.6297  High income
# 56         Finland          FIN        10.7         91.5144  High income
# 84         Iceland          ISL        13.4         96.5468  High income
# 102  Liechtenstein          LIE         9.2         93.8000  High income
# 106     Luxembourg          LUX        11.3         93.7765  High income
# 130    Netherlands          NLD        10.2         93.9564  High income
# 131         Norway          NOR        11.6         95.0534  High income
# 163         Sweden          SWE        11.8         94.7836  High income

# %%
#Select rows by multiple conditions using the "or" operator.

df[(df["Income Group"].isin(["High income", "Upper middle income"])) | (df["Birth rate"] <= 20)]
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244            78.9
# 2                            Angola          AGO      45.985            19.1
# 3                           Albania          ALB      12.877            57.2
# 4              United Arab Emirates          ARE      11.044            88.0
# 5                         Argentina          ARG      17.716            59.9
# ..                              ...          ...         ...             ...
# 183  St. Vincent and the Grenadines          VCT      16.306            52.0
# 184                   Venezuela, RB          VEN      19.842            54.9
# 185           Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                         Vietnam          VNM      15.537            43.9
# 191                    South Africa          ZAF      20.850            46.5
#
#             Income Group
# ...

# %%
#Select rows by multiple conditions and then select specific columns.

df[(df["Birth rate"] < 15) & (df["Internet users"] > 90)][["Country Code", "Country Name"]]
# Out:
#     Country Code   Country Name
# 22           BMU        Bermuda
# 47           DNK        Denmark
# 56           FIN        Finland
# 84           ISL        Iceland
# 102          LIE  Liechtenstein
# 106          LUX     Luxembourg
# 130          NLD    Netherlands
# 131          NOR         Norway
# 163          SWE         Sweden

# %%
df[df["Internet users"] > 2*df["Internet users"].mean()]["Country Name"]
# Out:
# 4      United Arab Emirates
# 17                  Bahrain
# 22                  Bermuda
# 30                   Canada
# 31              Switzerland
# 45                  Germany
# 47                  Denmark
# 56                  Finland
# 61           United Kingdom
# 84                  Iceland
# 89                    Japan
# 95              Korea, Rep.
# 102           Liechtenstein
# 106              Luxembourg
# 130             Netherlands
# 131                  Norway
# 145                   Qatar
# 163                  Sweden
# 181           United States
# Name: Country Name, dtype: object

# %%
df[df["Internet users"]/df["Birth rate"] == max(df["Internet users"]/df["Birth rate"])]["Country Code"]
# Out:
# 89    JPN
# Name: Country Code, dtype: object

# %% [markdown]
# ## Modifying the Dataframe's Structure

# %%
#Modify the columns' names.

new_names = {"Country Name": "Country", "Country Code": "Code", "Birth rate": "Birth_Rate", "Internet users": "Internet_Users", "Income Group": "Group"}
df = df.rename(columns = new_names)
df
# Out:
#                   Country Code  Birth_Rate  Internet_Users  \
# 0                   Aruba  ABW      10.244            78.9
# 1             Afghanistan  AFG      35.253             5.9
# 2                  Angola  AGO      45.985            19.1
# 3                 Albania  ALB      12.877            57.2
# 4    United Arab Emirates  ARE      11.044            88.0
# ..                    ...  ...         ...             ...
# 190           Yemen, Rep.  YEM      32.947            20.0
# 191          South Africa  ZAF      20.850            46.5
# 192      Congo, Dem. Rep.  COD      42.394             2.2
# 193                Zambia  ZMB      40.471            15.4
# 194              Zimbabwe  ZWE      35.715            18.5
#
#                    Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
#Set the index to be the country's code.

df = df.set_index("Code")
df
# Out:
#                    Country  Birth_Rate  Internet_Users                Group
# Code
# ABW                  Aruba      10.244            78.9          High income
# AFG            Afghanistan      35.253             5.9           Low income
# AGO                 Angola      45.985            19.1  Upper middle income
# ALB                Albania      12.877            57.2  Upper middle income
# ARE   United Arab Emirates      11.044            88.0          High income
# ...                    ...         ...             ...                  ...
# YEM            Yemen, Rep.      32.947            20.0  Lower middle income
# ZAF           South Africa      20.850            46.5  Upper middle income
# COD       Congo, Dem. Rep.      42.394             2.2           Low income
# ZMB                 Zambia      40.471            15.4  Lower middle income
# ZWE               Zimbabwe      35.715            18.5           Low income
#
# [195 rows x 4 columns]

# %%
df["Group"].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
#Replace the text in the "Group" column with numerical values.

mapping = {"Low income": 1, "Lower middle income": 2, "Upper middle income": 3, "High income": 4}
df["Group"] = df["Group"].replace(mapping)
df
# Out:
#                    Country  Birth_Rate  Internet_Users  Group
# Code
# ABW                  Aruba      10.244            78.9      4
# AFG            Afghanistan      35.253             5.9      1
# AGO                 Angola      45.985            19.1      3
# ALB                Albania      12.877            57.2      3
# ARE   United Arab Emirates      11.044            88.0      4
# ...                    ...         ...             ...    ...
# YEM            Yemen, Rep.      32.947            20.0      2
# ZAF           South Africa      20.850            46.5      3
# COD       Congo, Dem. Rep.      42.394             2.2      1
# ZMB                 Zambia      40.471            15.4      2
# ZWE               Zimbabwe      35.715            18.5      1
#
# [195 rows x 4 columns]

# %%
#Sort the countries by their share of internet users.

df = df.sort_values(by = "Internet_Users", ascending = False)
df
# Out:
#           Country  Birth_Rate  Internet_Users  Group
# Code
# ISL       Iceland      13.400         96.5468      4
# BMU       Bermuda      10.400         95.3000      4
# NOR        Norway      11.600         95.0534      4
# SWE        Sweden      11.800         94.7836      4
# DNK       Denmark      10.000         94.6297      4
# ...           ...         ...             ...    ...
# GIN        Guinea      37.337          1.6000      1
# SOM       Somalia      43.891          1.5000      1
# BDI       Burundi      44.151          1.3000      1
# TLS   Timor-Leste      35.755          1.1000      2
# ERI       Eritrea      34.800          0.9000      1
#
# [195 rows x 4 columns]

# %%
#Save the modifyed dataframe.

df.to_csv("countries_data.csv", index = True)

# %% [markdown]
# ## Modifying the Data

# %% [markdown]
# ### The apply() Method

# %%
#This method applies a given function to each column.

df[["Birth_Rate", "Internet_Users"]].apply(max)
# Out:
# Birth_Rate        49.6610
# Internet_Users    96.5468
# dtype: float64

# %%
#We can also apply a function to each row by passing "axis = 1" as an argument.

df[["Birth_Rate", "Internet_Users"]].apply(max, axis = 1)
# Out:
# Code
# ISL    96.5468
# BMU    95.3000
# NOR    95.0534
# SWE    94.7836
# DNK    94.6297
#         ...
# GIN    37.3370
# SOM    43.8910
# BDI    44.1510
# TLS    35.7550
# ERI    34.8000
# Length: 195, dtype: float64

# %%
#We can use the method to apply a lambda function.

df[["Birth_Rate", "Internet_Users"]].apply(lambda x: x*100)
# Out:
#       Birth_Rate  Internet_Users
# Code
# ISL       1340.0         9654.68
# BMU       1040.0         9530.00
# NOR       1160.0         9505.34
# SWE       1180.0         9478.36
# DNK       1000.0         9462.97
# ...          ...             ...
# GIN       3733.7          160.00
# SOM       4389.1          150.00
# BDI       4415.1          130.00
# TLS       3575.5          110.00
# ERI       3480.0           90.00
#
# [195 rows x 2 columns]

# %%
#Or we can apply a function we defined earlier.

def mean_division(col):
    return col / col.mean()

df[["Birth_Rate", "Internet_Users"]].apply(mean_division)
# Out:
#       Birth_Rate  Internet_Users
# Code
# ISL     0.624129        2.294556
# BMU     0.484398        2.264924
# NOR     0.540291        2.259063
# SWE     0.549606        2.252651
# DNK     0.465768        2.248993
# ...          ...             ...
# GIN     1.739037        0.038026
# SOM     2.044301        0.035649
# BDI     2.056411        0.030896
# TLS     1.665353        0.026143
# ERI     1.620872        0.021390
#
# [195 rows x 2 columns]

# %%
def third_world(row):
    if row.Internet_Users < 30 and row.Birth_Rate > 40:
        row.Group = "Third World"
    return row

df.apply(third_world, axis = 1)
# Out:
#           Country  Birth_Rate  Internet_Users        Group
# Code
# ISL       Iceland      13.400         96.5468            4
# BMU       Bermuda      10.400         95.3000            4
# NOR        Norway      11.600         95.0534            4
# SWE        Sweden      11.800         94.7836            4
# DNK       Denmark      10.000         94.6297            4
# ...           ...         ...             ...          ...
# GIN        Guinea      37.337          1.6000            1
# SOM       Somalia      43.891          1.5000  Third World
# BDI       Burundi      44.151          1.3000  Third World
# TLS   Timor-Leste      35.755          1.1000            2
# ERI       Eritrea      34.800          0.9000            1
#
# [195 rows x 4 columns]

# %%
#To save the modifications, simply overwrite the existing dataframe.

df = df.apply(third_world, axis = 1)
df
# Out:
#           Country  Birth_Rate  Internet_Users        Group
# Code
# ISL       Iceland      13.400         96.5468            4
# BMU       Bermuda      10.400         95.3000            4
# NOR        Norway      11.600         95.0534            4
# SWE        Sweden      11.800         94.7836            4
# DNK       Denmark      10.000         94.6297            4
# ...           ...         ...             ...          ...
# GIN        Guinea      37.337          1.6000            1
# SOM       Somalia      43.891          1.5000  Third World
# BDI       Burundi      44.151          1.3000  Third World
# TLS   Timor-Leste      35.755          1.1000            2
# ERI       Eritrea      34.800          0.9000            1
#
# [195 rows x 4 columns]

# %% [markdown]
# ### The applymap() Method

# %%
#This method applies a given function to each entry individually.

df.applymap(lambda k: np.sin(k) if type(k) != str else k)
# Out:
#           Country  Birth_Rate  Internet_Users        Group
# Code
# ISL       Iceland    0.740376        0.746358    -0.756802
# BMU       Bermuda   -0.827826        0.868526    -0.756802
# NOR        Norway   -0.822829        0.721261    -0.756802
# SWE        Sweden   -0.693525        0.510547    -0.756802
# DNK       Denmark   -0.544021        0.372703    -0.756802
# ...           ...         ...             ...          ...
# GIN        Guinea   -0.354250        0.999574     0.841471
# SOM       Somalia   -0.091170        0.997495  Third World
# BDI       Burundi    0.167904        0.963558  Third World
# TLS   Timor-Leste   -0.931123        0.891207     0.909297
# ERI       Eritrea   -0.240112        0.783327     0.841471
#
# [195 rows x 4 columns]

# %%
#Again, we can apply a function we defined earlier.

def change_entry(entry):
    if type(entry) != str:
        entry = entry**2 - 3*entry
    return entry

df[["Birth_Rate", "Internet_Users"]].applymap(change_entry)
# Out:
#        Birth_Rate  Internet_Users
# Code
# ISL    139.360000     9031.644190
# BMU     76.960000     8796.190000
# NOR     99.760000     8749.988652
# SWE    103.840000     8699.580029
# DNK     70.000000     8670.891022
# ...           ...             ...
# GIN   1282.040569       -2.240000
# SOM   1794.746881       -2.250000
# BDI   1816.857801       -2.210000
# TLS   1171.155025       -2.090000
# ERI   1106.640000       -1.890000
#
# [195 rows x 2 columns]

# %% [markdown]
# ### Inserting Missing Values

# %%
#Let's first insert a few NA values.

random_rows = np.random.choice(np.arange(0, 195), size = 50, replace = False)
random_columns = np.random.choice(np.arange(0, 4), size = 50, replace = True)

for index in list(zip(random_rows, random_columns)):
    df.iloc[index] = np.nan

df
# Out:
#           Country  Birth_Rate  Internet_Users        Group
# Code
# ISL       Iceland      13.400             NaN            4
# BMU       Bermuda      10.400         95.3000            4
# NOR           NaN      11.600         95.0534            4
# SWE        Sweden      11.800         94.7836            4
# DNK       Denmark      10.000         94.6297            4
# ...           ...         ...             ...          ...
# GIN        Guinea      37.337          1.6000            1
# SOM       Somalia      43.891          1.5000  Third World
# BDI       Burundi      44.151          1.3000  Third World
# TLS   Timor-Leste         NaN          1.1000            2
# ERI       Eritrea      34.800          0.9000          NaN
#
# [195 rows x 4 columns]

# %%
#How many NA values does the dataframe contain?

df.isna().sum().sum()
# Out:
# 50

# %%
#One way to get rid of (some of) the NA values is to apply a function that replaces these values with something else.

def replace_nan(entry):
    if type(entry) != str and np.isnan(entry):
        return 0
    else:
        return entry
    
df = df.applymap(replace_nan)

# %%
#Now, let's load the dataframe again and insert the NA values.

df = pd.read_csv("C:/Users/eruch/Dropbox/Macroeconomic Theory II/TA Section/2023/Python/Code Files/countries_data.csv")

random_rows = np.random.choice(np.arange(0, 195), size = 50, replace = False)
random_columns = np.random.choice(np.arange(0, 4), size = 50, replace = True)

for index in list(zip(random_rows, random_columns)):
    df.iloc[index] = np.nan

df, df.isna().sum().sum()
# Out:
# (    Code      Country  Birth_Rate  Internet_Users  Group
#  0    ISL      Iceland      13.400         96.5468      4
#  1    BMU      Bermuda      10.400         95.3000      4
#  2    NOR       Norway      11.600         95.0534      4
#  3    SWE       Sweden      11.800         94.7836      4
#  4    DNK      Denmark      10.000         94.6297      4
#  ..   ...          ...         ...             ...    ...
#  190  GIN       Guinea      37.337          1.6000      1
#  191  SOM      Somalia      43.891          1.5000      1
#  192  BDI      Burundi      44.151          1.3000      1
#  193  TLS  Timor-Leste      35.755          1.1000      2
#  194  ERI      Eritrea      34.800          0.9000      1
#
#  [195 rows x 5 columns],
#  50)

# %%
#Another way is to use the fillna() method.

df = df.fillna(df.mean())
df, df.isna().sum().sum()
# Out:
# (    Code      Country  Birth_Rate  Internet_Users  Group
#  0    ISL      Iceland      13.400         96.5468      4
#  1    BMU      Bermuda      10.400         95.3000      4
#  2    NOR       Norway      11.600         95.0534      4
#  3    SWE       Sweden      11.800         94.7836      4
#  4    DNK      Denmark      10.000         94.6297      4
#  ..   ...          ...         ...             ...    ...
#  190  GIN       Guinea      37.337          1.6000      1
#  191  SOM      Somalia      43.891          1.5000      1
#  192  BDI      Burundi      44.151          1.3000      1
#  193  TLS  Timor-Leste      35.755          1.1000      2
#  194  ERI      Eritrea      34.800          0.9000      1
#
#  [195 rows x 5 columns],
#  21)

# %% [markdown]
# ## Grouping and Visualizing Data

# %%
df = pd.read_csv("C:/Users/eruch/Dropbox/Macroeconomic Theory II/TA Section/2023/Python/Code Files/countries_data.csv")

# %%
#We can group data based on a specific column or columns, enabling us to perform aggregate operations or apply functions on those groups.

group_count = df.groupby("Group")["Birth_Rate", "Internet_Users"].count()
group_count
# Out:
# <ipython-input-40-00ba1bf30d9b>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_count = df.groupby("Group")["Birth_Rate", "Internet_Users"].count()
#        Birth_Rate  Internet_Users
# Group
# 1              30              30
# 2              50              50
# 3              48              48
# 4              67              67

# %%
group_means = df.groupby("Group")["Birth_Rate", "Internet_Users"].mean()
group_means
# Out:
# <ipython-input-41-023f7aeb4185>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_means = df.groupby("Group")["Birth_Rate", "Internet_Users"].mean()
#        Birth_Rate  Internet_Users
# Group
# 1       37.238267        5.988333
# 2       26.309140       22.366386
# 3       18.740646       40.279577
# 4       12.753433       74.231684

# %%
#Let's create a simple bar graph based on the means calculated above.

fig, ax = plt.subplots(figsize = (12, 9))

ax.bar(group_means.index - 0.2, group_means["Birth_Rate"], color = "b", width = 0.4, alpha = 0.7, label = "Birth Rate")
ax.bar(group_means.index + 0.2, group_means["Internet_Users"], color = "r", width = 0.4, alpha = 0.7, label = "Internet Users")

ax.set_xlabel("Group", font = "Serif", fontsize = 12)
ax.set_ylabel("Mean Values", font = "Serif", fontsize = 12)
ax.set_xticks(group_means.index)
ax.set_title("Mean Birth Rate and Internet Users by Group", font = "Serif", fontsize = 16)
ax.legend()

plt.show()

# %%
#Now, let's create a simple scatter plot of the relationship between a country's birth rate and the share of internet users, for each income group.

fig, ax = plt.subplots(figsize = (12, 10))

colors = ["r", "b", "g", "black"]

for i in range(1, 5):
    income_group = df[df["Group"] == i]
    ax.scatter(income_group["Birth_Rate"], income_group["Internet_Users"], color = colors[i-1], label = "Income Group {}".format(i))
    
ax.set_xlabel("Birth Rate", font = "Serif", fontsize = 12)
ax.set_ylabel("Internet Users", font = "Serif", fontsize = 12)
ax.legend()

plt.show()

# %% [markdown]
# ## Running Simple Regressions

# %%
#Let's regress a country's birth rate on the share of internet users and a set of income group dummy variables.

#We import the necessary library to perform an OLS regression.
import statsmodels.api as sm

#We add three columns represneting the three highest income groups: lower middle, upper middle, and high.
for column, group in zip(["Lower_Middle", "Upper_Middle", "High"], [2, 3, 4]):
    df[column] = df["Group"].apply(lambda value: 1 if value == group else 0)
    
#We add three columns representing the interaction terms.
for interaction, column in zip(["IU_Lower_Middle", "IU_Upper_Middle", "IU_High"], ["Lower_Middle", "Upper_Middle", "High"]):
    df[interaction] = df[column] * df["Internet_Users"]
    
#We add a column for the intercept.
df["Intercept"] = 1

#We define the dependent variable and a vector containing the explanatory variables.
y, X = df["Birth_Rate"], df[["Intercept", "Internet_Users", "Lower_Middle", "Upper_Middle", "High", "IU_Lower_Middle", "IU_Upper_Middle", "IU_High"]]

#We fit the OLS model
model = sm.OLS(y, X)

#We make sure to calculate robust standard errors.
results = model.fit(cov_type = "HC3")

#Finally, we present the results.
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Birth_Rate   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     97.15
# Date:                Thu, 01 Jun 2023   Prob (F-statistic):           7.49e-59
# Time:                        18:46:52   Log-Likelihood:                -605.79
# No. Observations:                 195   AIC:                             1228.
# Df Residuals:                     187   BIC:                             1254.
# Df Model:                           7
# Covariance Type:                  HC3
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...
